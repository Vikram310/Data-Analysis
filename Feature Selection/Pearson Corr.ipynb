# %% [markdown]
# ## Feature Selection- With Correlation¶

# %% [markdown]
# In this step we will be removing the features which are highly correlated

# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import load_boston
data = load_boston()
df = pd.DataFrame(data.data, columns = data.feature_names)
df['MEDV'] = data.target

# %%
data.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
X = df.drop('MEDV',axis=1)
Y = df['MEDV']

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
X.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
#seperating the dataset 
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.28,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((364, 13), (142, 13))

# %%
X_train.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.195279  0.387538 -0.048357  0.422893 -0.196225  0.333369
# ZN      -0.195279  1.000000 -0.523188 -0.062467 -0.519320  0.321099 -0.580351
# INDUS    0.387538 -0.523188  1.000000  0.046645  0.752760 -0.401245  0.625147
# CHAS    -0.048357 -0.062467  0.046645  1.000000  0.045784  0.085874  0.069141
# NOX      0.422893 -0.519320  0.752760  0.045784  1.000000 -0.288487  0.741943
# RM      -0.196225  0.321099 -0.401245  0.085874 -0.288487  1.000000 -0.244472
# AGE      0.333369 -0.580351  0.625147  0.069141  0.741943 -0.244472  1.000000
# DIS     -0.360906  0.654986 -0.689989 -0.086701 -0.768308  0.193501 -0.759424
# RAD      0.608202 -0.311553  0.585209  0.023394  0.633618 -0.190013  0.442992
# TAX      0.564426 -0.315922  0.722657 -0.015248  0.685970 -0.283456  0.497825
# PTRATIO  0.267097 -0.393949  0.388899 -0.073140  0.184903 -0.389013  0.245699
# ...

# %%
import seaborn as sns
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot = True, cmap = plt.cm.RdBu_r)
plt.show()

# %%
# with the following function, we can select some highly correlated features.
# it will remove the first feature that is correlated with any other feature

def correlation(dataset,threshold):
    col_corr = set() #set of all highly correlated features names
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train,0.65)
len(set(corr_features))
# Out:
# 4

# %%
corr_features
# Out:
# {'AGE', 'DIS', 'NOX', 'TAX'}

# %%
X_train.drop(corr_features,axis=1)
X_test.drop(corr_features,axis=1)
# Out:
#          CRIM    ZN  INDUS  CHAS     RM   RAD  PTRATIO       B  LSTAT
# 329   0.06724   0.0   3.24   0.0  6.333   4.0     16.9  375.21   7.34
# 371   9.23230   0.0  18.10   0.0  6.216  24.0     20.2  366.15   9.53
# 219   0.11425   0.0  13.89   1.0  6.373   5.0     16.4  393.74  10.50
# 403  24.80170   0.0  18.10   0.0  5.349  24.0     20.2  396.90  19.77
# 78    0.05646   0.0  12.83   0.0  6.232   5.0     18.7  386.40  12.34
# ..        ...   ...    ...   ...    ...   ...      ...     ...    ...
# 142   3.32105   0.0  19.58   1.0  5.403   5.0     14.7  396.90  26.82
# 249   0.19073  22.0   5.86   0.0  6.718   7.0     19.1  393.74   6.56
# 415  18.08460   0.0  18.10   0.0  6.434  24.0     20.2   27.25  29.05
# 378  23.64820   0.0  18.10   0.0  6.380  24.0     20.2  396.90  23.69
# 494   0.27957   0.0   9.69   0.0  5.926   6.0     19.2  396.90  13.59
#
# [142 rows x 9 columns]

# %% [markdown]
# ### Let's try with Big dataset

# %%
df=pd.read_csv('Santandra.csv',nrows=10000)
X=df.drop(labels=['TARGET'], axis=1)
y=df['TARGET']
# separate dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(
    df.drop(labels=['TARGET'], axis=1),
    df['TARGET'],
    test_size=0.3,
    random_state=0)

# %%
import seaborn as sns
#Using Pearson Correlation
corrmat = X_train.corr()
fig, ax = plt.subplots()
fig.set_size_inches(12,12)
sns.heatmap(corrmat)

# %%
corr_features = correlation(X_train, 0.9)
len(set(corr_features))
# Out:
# 155

# %%
corr_features
# Out:
# {'delta_num_aport_var13_1y3',
#  'delta_num_aport_var17_1y3',
#  'delta_num_aport_var33_1y3',
#  'delta_num_compra_var44_1y3',
#  'delta_num_reemb_var13_1y3',
#  'delta_num_trasp_var17_in_1y3',
#  'delta_num_trasp_var33_in_1y3',
#  'delta_num_venta_var44_1y3',
#  'imp_aport_var17_ult1',
#  'imp_aport_var33_hace3',
#  'imp_op_var39_efect_ult1',
#  'imp_op_var39_efect_ult3',
#  'imp_op_var39_ult1',
#  'imp_op_var40_efect_ult3',
#  'imp_op_var40_ult1',
#  'imp_reemb_var13_ult1',
#  'imp_trasp_var17_in_ult1',
#  'imp_trasp_var33_in_ult1',
#  'imp_venta_var44_ult1',
#  'ind_var10cte_ult1',
#  'ind_var13',
#  'ind_var13_corto',
#  'ind_var13_largo',
#  'ind_var20',
#  'ind_var24',
#  'ind_var25',
#  'ind_var25_0',
#  'ind_var26',
#  'ind_var26_0',
#  'ind_var26_cte',
#  'ind_var29',
#  'ind_var29_0',
#  'ind_var31',
#  'ind_var32',
#  'ind_var32_0',
#  'ind_var37',
#  'ind_var37_0',
#  'ind_var39',
#  'ind_var40',
#  'ind_var40_0',
#  'ind_var41_0',
#  'ind_var44',
#  'ind_var6',
# ...

# %%
X_train.drop(corr_features,axis=1)
# Out:
#          ID  var3  var15  imp_ent_var16_ult1  imp_op_var39_comer_ult1  \
# 7681  15431     2     42               840.0                  4477.02
# 9031  18181     2     31                 0.0                    52.32
# 3691   7411     2     51                 0.0                     0.00
# 202     407     2     36                 0.0                     0.00
# 5625  11280     2     23                 0.0                     0.00
# ...     ...   ...    ...                 ...                      ...
# 9225  18564     2     33                 0.0                     0.00
# 4859   9723     2     24                 0.0                     0.00
# 3264   6557     2     24                 0.0                     0.00
# 9845  19796     2     38                 0.0                     0.00
# 2732   5441     2     23                 0.0                     0.00
#
#       imp_op_var39_comer_ult3  imp_op_var40_comer_ult1  \
# 7681                  4989.54                      0.0
# ...
